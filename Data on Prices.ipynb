# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)   # Show all rows
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'left')

df = pd.read_csv("Dietary Food List - Nutrients.csv", header=None)

foods = df.iloc[0, 1:].tolist()

row_map = {
    25: ("Haiti", "Import"),
    26: ("Haiti", "Local"),
}
output = []
choices = ["Not Tracked", "No Specific Data"]

for row_idx, (country, type_) in row_map.items():
    # Row values for foods (skip first column)
    row_values = df.iloc[row_idx, 1:].tolist()
    for food, val in zip(foods, row_values):
        # Keep $ sign, fill missing
        if pd.isna(val) or str(val).strip() == '':
            price = np.random.choice(choices)
        else:
            price = str(val).strip()
        output.append({
            "Country": country,
            "Type": type_,
            "Food": food,
            "Price_USD": price
        })

tidy_prices = pd.DataFrame(output, columns=["Country", "Type", "Food", "Price_USD"])

country_order = ['Haiti']
type_order = ['Local', 'Import']
tidy_prices['Country'] = pd.Categorical(tidy_prices['Country'], categories=country_order, ordered=True)
tidy_prices['Type'] = pd.Categorical(tidy_prices['Type'], categories=type_order, ordered=True)

tidy_prices = tidy_prices.sort_values(['Country','Type','Food']).reset_index(drop=True)

print(tidy_prices)
# Out:
#    Country Type    Food                                               Price_USD
# 0   Haiti    Local                                      Beans (Black)                 $0.28
# 1   Haiti    Local           Beef(Bovine Meat) ; (80% lean, 20% fat)                  $1.10
# 2   Haiti    Local                Bread (white, enriched, unbleached)                 $0.49
# 3   Haiti    Local                               Cabbage (green, raw)                 $0.20
# 4   Haiti    Local                                            Cassava                 $0.20
# 5   Haiti    Local                                            Cheese                  $0.82
# 6   Haiti    Local                                            Chicken                 $1.70
# 7   Haiti    Local                                               Corn                 $1.00
# 8   Haiti    Local  Dried/Salted/Smoked/Brined Fish (Fish, cod, At...  Not locally produced
# 9   Haiti    Local                      Edible Offal (beef liver raw)  Not locally produced
# 10  Haiti    Local                   Edible Offal (chicken liver raw)  Not locally produced
# 11  Haiti    Local                      Edible Offal (lamb liver raw)  Not locally produced
# 12  Haiti    Local                          Edible Offal (pork liver)  Not locally produced
# 13  Haiti    Local                                               Eggs                 $0.25
# 14  Haiti    Local                                  Fish Fillet (cod)  Not locally produced
# 15  Haiti    Local                                          Fish/tuna                 $0.48
# 16  Haiti    Local                                              Mango                 $4.50
# 17  Haiti    Local                                Onion (yellow, raw)                 $0.26
# 18  Haiti    Local              Pig Meat (pork belly, with skin, raw)  Not locally produced
# 19  Haiti    Local                                          Raw Sugar                 $0.35
# 20  Haiti    Local          Rice (white, long grain, unenriched, raw)                 $0.31
# 21  Haiti    Local                                        Soybean Oil                 $0.10
# 22  Haiti    Local                                              Wheat  Not locally produced
# 23  Haiti    Local                                           avocados                 $0.60
# 24  Haiti    Local                                            coconut                 $0.20
# 25  Haiti    Local                                               lime                 $0.15
# 26  Haiti    Local                                         maize/corn      No specific data
# 27  Haiti    Local                                            oranges                 $0.10
# 28  Haiti    Local                                            papayas                 $0.17
# 29  Haiti    Local                                          plantains                 $0.20
# 30  Haiti    Local                                 shiitake mushrooms      No specific data
# 31  Haiti    Local                                     sweet potatoes                 $0.30
# 32  Haiti    Local                                               yams                 $0.22
# 33  Haiti    Local                                                NaN      No Specific Data
# 34  Haiti   Import                                      Beans (Black)                 $0.46
# 35  Haiti   Import           Beef(Bovine Meat) ; (80% lean, 20% fat)                  $1.10
# 36  Haiti   Import                Bread (white, enriched, unbleached)                 $1.58
# 37  Haiti   Import                               Cabbage (green, raw)                 $0.45
# 38  Haiti   Import                                            Cassava          Not Imported
# 39  Haiti   Import                                            Cheese                  $0.82
# 40  Haiti   Import                                            Chicken                 $1.82
# 41  Haiti   Import                                               Corn                 $1.20
# 42  Haiti   Import  Dried/Salted/Smoked/Brined Fish (Fish, cod, At...                 $1.30
# 43  Haiti   Import                      Edible Offal (beef liver raw)      No specific data
# 44  Haiti   Import                   Edible Offal (chicken liver raw)                 $0.47
# 45  Haiti   Import                      Edible Offal (lamb liver raw)      No specific data
# 46  Haiti   Import                          Edible Offal (pork liver)      No specific data
# 47  Haiti   Import                                               Eggs                 $0.50
# 48  Haiti   Import                                  Fish Fillet (cod)                 $0.65
# 49  Haiti   Import                                          Fish/tuna                 $0.53
# 50  Haiti   Import                                              Mango                 $4.80
# 51  Haiti   Import                                Onion (yellow, raw)                 $0.47
# 52  Haiti   Import              Pig Meat (pork belly, with skin, raw)                 $1.20
# 53  Haiti   Import                                          Raw Sugar                 $0.50
# 54  Haiti   Import          Rice (white, long grain, unenriched, raw)                 $0.77
# 55  Haiti   Import                                        Soybean Oil                 $0.18
# 56  Haiti   Import                                              Wheat                 $0.60
# 57  Haiti   Import                                           avocados          Not imported
# 58  Haiti   Import                                            coconut          Not imported
# 59  Haiti   Import                                               lime          Not imported
# 60  Haiti   Import                                         maize/corn      No specific data
# 61  Haiti   Import                                            oranges          Not imported
# 62  Haiti   Import                                            papayas          Not imported
# 63  Haiti   Import                                          plantains      No specific data
# 64  Haiti   Import                                 shiitake mushrooms          Not imported
# 65  Haiti   Import                                     sweet potatoes          Not imported
# 66  Haiti   Import                                               yams          Not imported
# 67  Haiti   Import                                                NaN           Not Tracked
