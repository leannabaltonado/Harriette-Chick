# %%
# Install
# %pip install -r requirements.txt --upgrade
# %pip install wbdata
# Out:
# Collecting Pint>=0.25 (from -r requirements.txt (line 1))
#   Using cached pint-0.25.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=2.0 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.2.6)
# Collecting numpy>=2.0 (from -r requirements.txt (line 2))
#   Using cached numpy-2.4.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas>=2.0 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.2.3)
# Collecting pandas>=2.0 (from -r requirements.txt (line 3))
#   Using cached pandas-3.0.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: requests>=2.32 in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (2.32.3)
# Collecting requests>=2.32 (from -r requirements.txt (line 4))
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting scipy>=1.17 (from -r requirements.txt (line 5))
#   Using cached scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: gspread in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (5.12.4)
# Collecting gspread (from -r requirements.txt (line 6))
#   Using cached gspread-6.2.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: gspread_pandas in /srv/conda/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (2.2.3)
# Collecting gspread_pandas (from -r requirements.txt (line 7))
#   Using cached gspread_pandas-3.3.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting bottleneck>=1.6 (from -r requirements.txt (line 8))
#   Using cached bottleneck-1.6.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (8.2 kB)
# Collecting eep153_tools (from -r requirements.txt (line 9))
#   Using cached eep153_tools-0.12.4-py2.py3-none-any.whl.metadata (363 bytes)
# Collecting fooddatacentral>=1.0.11 (from -r requirements.txt (line 10))
#   Using cached fooddatacentral-1.0.12-py3-none-any.whl.metadata (2.1 kB)
# Collecting python-gnupg (from -r requirements.txt (line 11))
#   Using cached python_gnupg-0.5.6-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting flexcache>=0.3 (from Pint>=0.25->-r requirements.txt (line 1))
#   Using cached flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.4 (from Pint>=0.25->-r requirements.txt (line 1))
#   Using cached flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: platformdirs>=2.1.0 in /srv/conda/lib/python3.11/site-packages (from Pint>=0.25->-r requirements.txt (line 1)) (4.3.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /srv/conda/lib/python3.11/site-packages (from Pint>=0.25->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/lib/python3.11/site-packages (from pandas>=2.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests>=2.32->-r requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests>=2.32->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests>=2.32->-r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests>=2.32->-r requirements.txt (line 4)) (2026.2.25)
# Requirement already satisfied: google-auth>=1.12.0 in /srv/conda/lib/python3.11/site-packages (from gspread->-r requirements.txt (line 6)) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /srv/conda/lib/python3.11/site-packages (from gspread->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: decorator in /srv/conda/lib/python3.11/site-packages (from gspread_pandas->-r requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /srv/conda/lib/python3.11/site-packages (from google-auth>=1.12.0->gspread->-r requirements.txt (line 6)) (6.2.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/lib/python3.11/site-packages (from google-auth>=1.12.0->gspread->-r requirements.txt (line 6)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/lib/python3.11/site-packages (from google-auth>=1.12.0->gspread->-r requirements.txt (line 6)) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /srv/conda/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth>=1.12.0->gspread->-r requirements.txt (line 6)) (0.6.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /srv/conda/lib/python3.11/site-packages (from google-auth-oauthlib>=0.4.1->gspread->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread->-r requirements.txt (line 6)) (3.3.1)
# Using cached pint-0.25.2-py3-none-any.whl (306 kB)
# Using cached numpy-2.4.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
# Using cached pandas-3.0.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.3 MB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached scipy-1.17.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
# Using cached gspread_pandas-3.3.0-py2.py3-none-any.whl (27 kB)
# Using cached bottleneck-1.6.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (375 kB)
# Using cached eep153_tools-0.12.4-py2.py3-none-any.whl (4.9 kB)
# Using cached fooddatacentral-1.0.12-py3-none-any.whl (6.9 kB)
# Using cached python_gnupg-0.5.6-py2.py3-none-any.whl (22 kB)
# Using cached flexcache-0.3-py3-none-any.whl (13 kB)
# Using cached flexparser-0.4-py3-none-any.whl (27 kB)
# Installing collected packages: python-gnupg, fooddatacentral, eep153_tools, requests, numpy, flexparser, flexcache, scipy, Pint, pandas, bottleneck, gspread_pandas
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:m╺━━━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [numpy]
#       Successfully uninstalled numpy-2.2.6━━━━━━━━━━━━━━━━━━━━━━━━  4/12 [numpy]
#   Attempting uninstall: scipy╸━━━━━━━━━━━━━━━━━━━━━━━  5/12 [flexparser]
#     Found existing installation: scipy 1.14.1━━━━━━━━━━━━━━━━━  5/12 [flexparser]
#     Uninstalling scipy-1.14.1:━━━━━━━━━━━━━━━━━━━━━━━  5/12 [flexparser]
#       Successfully uninstalled scipy-1.14.10m━━━━━━━━━━━━━━━━  7/12 [scipy]]
#   Attempting uninstall: pandas━━━━╸━━━━━━━━━━━━━  8/12 [Pint]]
#     Found existing installation: pandas 2.2.3━━━━━━━━━━━━━  8/12 [Pint]
#     Uninstalling pandas-2.2.3:━━━━━━━━╺━━━━━━━━━  9/12 [pandas]
#       Successfully uninstalled pandas-2.2.3╺━━━━━━━━━  9/12 [pandas]
#   Attempting uninstall: gspread_pandas╺━━━━━━━━━  9/12 [pandas]
#     Found existing installation: gspread-pandas 2.2.3━━━━━━━━━  9/12 [pandas]
#     Uninstalling gspread-pandas-2.2.3:╺━━━━━━━━━  9/12 [pandas]
#       Successfully uninstalled gspread-pandas-2.2.30m━━━━━━━━━  9/12 [pandas]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [gspread_pandas]andas]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# linearmodels 0.0.0 requires Cython>=3.0.10, which is not installed.
# linearmodels 0.0.0 requires setuptools_scm[toml]<9.0.0,>=8.0.0, which is not installed.
# otter-grader 6.1.3 requires wrapt<2.0.0,>=1.16.0, but you have wrapt 2.1.1 which is incompatible.
# ibis-framework 9.2.0 requires pandas<3,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# Successfully installed Pint-0.25.2 bottleneck-1.6.0 eep153_tools-0.12.4 flexcache-0.3 flexparser-0.4 fooddatacentral-1.0.12 gspread_pandas-3.3.0 numpy-2.4.3 pandas-3.0.1 python-gnupg-0.5.6 requests-2.32.5 scipy-1.17.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting wbdata
#   Using cached wbdata-1.1.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting appdirs<2,>=1.4 (from wbdata)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: backoff<3,>=2.2.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.2.1)
# Collecting cachetools<6,>=5.3.2 (from wbdata)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dateparser<2,>=1.2.0 (from wbdata)
#   Using cached dateparser-1.3.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: decorator<6,>=5.1.1 in /srv/conda/lib/python3.11/site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3,>=2.0 in /srv/conda/lib/python3.11/site-packages (from wbdata) (2.32.5)
# Collecting shelved-cache<0.4,>=0.3.1 (from wbdata)
#   Using cached shelved_cache-0.3.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tabulate<1,>=0.8.5 (from wbdata)
#   Using cached tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /srv/conda/lib/python3.11/site-packages (from dateparser<2,>=1.2.0->wbdata) (2026.2.28)
# Collecting tzlocal>=0.2 (from dateparser<2,>=1.2.0->wbdata)
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.0->wbdata) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.11/site-packages (from python-dateutil>=2.7.0->dateparser<2,>=1.2.0->wbdata) (1.17.0)
# Using cached wbdata-1.1.0-py3-none-any.whl (18 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached dateparser-1.3.0-py3-none-any.whl (318 kB)
# Using cached shelved_cache-0.3.1-py3-none-any.whl (7.8 kB)
# Using cached tabulate-0.10.0-py3-none-any.whl (39 kB)
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: appdirs, tzlocal, tabulate, cachetools, shelved-cache, dateparser, wbdata
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.6
#     Uninstalling cachetools-6.2.6:
#       Successfully uninstalled cachetools-6.2.6
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [wbdata]2m5/7 [dateparser]
# Successfully installed appdirs-1.4.4 cachetools-5.5.2 dateparser-1.3.0 shelved-cache-0.3.1 tabulate-0.10.0 tzlocal-5.3.1 wbdata-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import 
import fooddatacentral as fdc
import pandas as pd
import numpy as np
from datascience import *
from scipy.optimize import linprog
import wbdata
import warnings 
import matplotlib.pyplot as plt
# %matplotlib inline

apikey = "hhXDThEWfQoAua41aVdG81iaAHEhLCC0An6FqziG"
warnings.filterwarnings('ignore')

# %%
# [A] Dietary Reference Intake

# Reading Table
df_min = Table.read_table('Dietary Requirements - diet_minimums.csv')
df_max = Table.read_table('Dietary Requirements - diet_maximums.csv')

#Sex: Type F or M
def dri(age, sex):
    if age <= 3:
        sex = 'C'
        age_t = '1-3'
    elif 4 <= age <= 8:
        age_t = '4-8'
    elif 9 <= age <= 13:
        age_t = '9-13'
    elif 14 <= age <= 18:
        age_t = '14-18'
    elif 19 <= age <= 30:
        age_t = '19-30'
    elif 31 <= age <= 50:
        age_t = '31-50'
    else:
        age_t = '51+'

    column = sex + " " + age_t

    # Some nutrients does not have a maximum so it should be infinite
    # Using 99999999 because later linprog function does not allow float('Inf')
    # But 99999999 would be fair as it is a really big number
    data = {
            'Nutrition': np.insert(df_min.column("Nutrition"), 0, 'Sodium, Na') ,
            'max': np.append(df_max.column(column), [99999999]*(len(df_min.column(column))-1)),
            'min': np.insert(df_min.column(column), 0, 0) 
            }

    return pd.DataFrame(data)


# Testings: 
dri(20, 'F')
# Out:
#                          Nutrition       max     min
# 0                       Sodium, Na      2300     0.0
# 1                           Energy      3100  2000.0
# 2                          Protein  99999999    46.0
# 3             Fiber, total dietary  99999999    28.0
# 4                      Folate, DFE  99999999   400.0
# 5                      Calcium, Ca  99999999  1000.0
# 6      Carbohydrate, by difference  99999999   130.0
# 7                         Iron, Fe  99999999    18.0
# 8                    Magnesium, Mg  99999999   310.0
# 9                           Niacin  99999999    14.0
# 10                   Phosphorus, P  99999999   700.0
# 11                    Potassium, K  99999999  4700.0
# 12                      Riboflavin  99999999     1.1
# 13                         Thiamin  99999999     1.1
# 14                  Vitamin A, RAE  99999999   700.0
# 15                    Vitamin B-12  99999999     2.4
# 16                     Vitamin B-6  99999999     1.3
# 17  Vitamin C, total ascorbic acid  99999999    75.0
# 18    Vitamin E (alpha-tocopherol)  99999999    15.0
# 19       Vitamin K (phylloquinone)  99999999    90.0
# 20                        Zinc, Zn  99999999     8.0

# %%
# [A] Nutritional content of different foods

# Put an FDC ID HERE!
id =  [['chicken',2727569],['rice', 1999628]] 

def nutrition_table(id):
    # List of nutrient
    nutrient_df = pd.DataFrame({
                    'Nutrition': np.insert(df_min.column("Nutrition"), 0, 'Sodium, Na') ,
                    })
    
    for i in id:
        # Modifying data
        food_nutrient = fdc.nutrients(apikey,fdc_id=i[1])
        food_nutrient = food_nutrient.rename(index={"Energy (Atwater General Factors)": "Energy"})
        food_nutrient = food_nutrient.reset_index().rename(columns={'index': 'Nutrition','Quantity':i[0]}).drop("Units", axis=1)
        food_nutrient[food_nutrient.select_dtypes("number").columns] = food_nutrient.select_dtypes("number").clip(lower=0)
        
        
        nutrient_df = pd.merge(nutrient_df, food_nutrient, on='Nutrition', how='left')
        
    return nutrient_df.fillna(0)


# Testings: 
nutrition_table(id)
# Out:
#                          Nutrition    chicken        rice
# 0                       Sodium, Na   48.07000    0.936300
# 1                           Energy  126.90500   44.095000
# 2                          Protein   21.40625    2.414375
# 3             Fiber, total dietary    0.00000    4.166000
# 4                      Folate, DFE    0.00000    0.000000
# 5                      Calcium, Ca    6.89800    0.766300
# 6      Carbohydrate, by difference    0.00000    8.170625
# 7                         Iron, Fe    0.35350    0.144300
# 8                    Magnesium, Mg   25.40000   14.060000
# 9                           Niacin    0.00000    2.741000
# 10                   Phosphorus, P  203.60000   75.820000
# 11                    Potassium, K  332.50000  243.000000
# 12                      Riboflavin    0.00000    0.216300
# 13                         Thiamin    0.00000    0.001250
# 14                  Vitamin A, RAE    0.00000    0.000000
# 15                    Vitamin B-12    0.00000    0.000000
# 16                     Vitamin B-6    0.00000    0.159300
# 17  Vitamin C, total ascorbic acid    0.00000    0.000000
# 18    Vitamin E (alpha-tocopherol)    0.00000    0.000000
# 19       Vitamin K (phylloquinone)    0.00000    0.000000
# 20                        Zinc, Zn    0.62450    0.764100

# %%
# [A] Solution - Part A: Producing 'A' 'B'

# Producing A_ub using the nutrition table generate from the function above\n",
def A_ub_function(df_nutrient_table):
    A_ub = []
    for i in range(len(df_nutrient_table)):
        A_ub.append(list(df_nutrient_table.iloc[i][1:]))

    for i in range(len(A_ub)):
        negative_a_ub = []
        for j in range(len(A_ub[0])):
            negative_a_ub.append(-A_ub[i][j])
        A_ub.append(negative_a_ub)

    return A_ub


# Producing A_ub using the google sheet we manually input\n",
df_nutrition = Table.read_table('Food_Local.csv')

def A_ub_sheet(df_sheet):
    A_ub = []
    for i in range(len(df_sheet[0])):
        A_ub.append(list(df_sheet.row(i))[2:]) # [2:] as exlduing the first column of food and the second column of units

    for i in range(len(A_ub)):
        negative_a_ub = []
        for j in range(len(A_ub[0])):
            negative_a_ub.append(-A_ub[i][j])
        A_ub.append(negative_a_ub)
    return A_ub

# Producing b_ub with given age and gender
def b_ub_age_gender(age, gender):
    restrictions = dri(age, gender)
    b_ub = list(restrictions["max"]) + list(-restrictions["min"])
    return b_ub


# Producing the list of cost, assuming the cost is on the first row
df_price = Table.read_table('Price_Local.csv')

def cost_sheet(df):
    return list(df.row(0))

# Testings:
# A_ub_function(nutrition_table(id))
# A_ub_sheet(df_nutrition)
# b_ub_age_gender(20, 'F')

# %%
# [A] Solution - Part B: Solving the Problem with 'linprog'
# Exploring Local food (local only)

# defining 'A'
A_ub = A_ub_sheet(df_nutrition)

# defining cost
c = cost_sheet(df_price)

# defining 'b'
b_ub = b_ub_age_gender(20, 'F')

# Defining food_list
food_list = list(df_nutrition.labels)[2:] #[2:] becasue to exclude the nutrient column and unit column

# Assumption: A_ub, the cost and the list of food have the same order
def minimum_cost(A_ub, b_ub, c, food_list):
    # Bound for the x
    bounds = []
    for i in range(len(A_ub[0])):
        bounds.append((0, None))
    
    # Solving the problem and showing it in dataframe
    solution = linprog(c, A_ub=A_ub, b_ub=b_ub, bounds=bounds)

    df = pd.DataFrame({'Food': food_list,
            'Quantity (100g)': solution.x})
    return df


# input of food_amount is expected to be the dataframe produced from minimum_cost() function
def total_nutrients(A_ub, food_amount):
    new_A_ub = A_ub[:int(len(A_ub)/2)]
    ttl_nutrients = []
    food_amount_list = list(food_amount['Quantity (100g)'])
    
    for i in new_A_ub:
        total = 0
        for j in range(len(i)):
            total += food_amount_list[j]*i[j]
        ttl_nutrients.append(total)

    data = {
            'Nutrition': np.insert(df_min.column("Nutrition"), 0, 'Sodium, Na') ,
            'Total_nutrients': ttl_nutrients
            }
            
    return pd.DataFrame(data)
    
    
local_food = minimum_cost(A_ub, b_ub, c, food_list)
local_food
# Out:
#                                          Food  Quantity (100g)
# 0                        Cabbage (green, raw)         0.958180
# 1                                       Mango         0.000000
# 2                                     Chicken         0.000000
# 3   Rice (white, long grain, unenriched, raw)         0.000000
# 4                                 Soybean Oil         1.122487
# 5         Bread (white, enriched, unbleached)         0.000000
# 6                         Onion (yellow, raw)         0.000000
# 7                                   Raw Sugar         0.000000
# 8                               Beans (Black)         1.779426
# 9                                   Fish/tuna         0.000000
# 10                                       Eggs         1.589737
# 11                                       Corn         0.000000
# 12                                    Cheese          0.734404
# 13   Beef(Bovine Meat) ; (80% lean, 20% fat)          0.000000
# 14                                    Cassava         0.000000
# 15                                  plantains         0.000000
# 16                                 maize/corn        10.783699
# 17                             sweet potatoes         0.000000
# 18                                       yams         0.121205
# 19                                   avocados         0.000000
# 20                                    papayas         0.000000
# 21                                    coconut         0.000000
# 22                                    oranges         0.000000
# 23                                       lime         0.000000
# 24                         shiitake mushrooms         0.000000

# %%
# Filtering and excluding the 0 from the local food list 
local_food[local_food['Quantity (100g)'] != 0]
# Out:
#                     Food  Quantity (100g)
# 0   Cabbage (green, raw)         0.958180
# 4            Soybean Oil         1.122487
# 8          Beans (Black)         1.779426
# 10                  Eggs         1.589737
# 12               Cheese          0.734404
# 16            maize/corn        10.783699
# 18                  yams         0.121205

# %%
# Total nutrients of local food only with minimum cost diet
total_nutrients(A_ub, local_food)
# Out:
#                          Nutrition  Total_nutrients
# 0                       Sodium, Na       881.224092
# 1                           Energy      2487.022435
# 2                          Protein       116.623661
# 3             Fiber, total dietary        30.609024
# 4                      Folate, DFE       582.421222
# 5                      Calcium, Ca      1000.000000
# 6      Carbohydrate, by difference       211.473778
# 7                         Iron, Fe        18.000000
# 8                    Magnesium, Mg       772.841299
# 9                           Niacin        19.494917
# 10                   Phosphorus, P      2547.954662
# 11                    Potassium, K      6177.739159
# 12                      Riboflavin         1.590348
# 13                         Thiamin         1.820271
# 14                  Vitamin A, RAE       700.000000
# 15                    Vitamin B-12         2.400000
# 16                     Vitamin B-6         1.300000
# 17  Vitamin C, total ascorbic acid       113.531608
# 18    Vitamin E (alpha-tocopherol)        15.000000
# 19       Vitamin K (phylloquinone)        90.000000
# 20                        Zinc, Zn        15.867342

# %%
# Exploring Local and import 

df_nutrition_LI = Table.read_table('Food_Import_Local.csv')
df_price_LI = Table.read_table('Price_Import_Local.csv')

# defining 'A'
A_ub_LI = A_ub_sheet(df_nutrition_LI)

# defining cost
c_LI = cost_sheet(df_price_LI)

# defining 'b'
b_ub_LI = b_ub_age_gender(20, 'F')

# Defining food_list
food_list_LI = list(df_nutrition_LI.labels)[2:]

local_import_food = minimum_cost(A_ub_LI, b_ub_LI, c_LI, food_list_LI)
local_import_food
# Out:
#                                                  Food  Quantity (100g)
# 0                                Cabbage (green, raw)         0.000000
# 1                                               Mango         0.000000
# 2                                             Chicken         0.000000
# 3           Rice (white, long grain, unenriched, raw)         0.000000
# 4                                         Soybean Oil         1.080714
# 5                 Bread (white, enriched, unbleached)         0.000000
# 6                                 Onion (yellow, raw)         0.000000
# 7                                           Raw Sugar         0.000000
# 8                                       Beans (Black)         0.211583
# 9                                           Fish/tuna         0.000000
# 10                                               Eggs         0.000000
# 11                                               Corn         0.000000
# 12                                            Cheese          1.310191
# 13                                              Wheat         0.000000
# 14           Beef(Bovine Meat) ; (80% lean, 20% fat)          0.000000
# 15              Pig Meat (pork belly, with skin, raw)         0.000000
# 16                   Edible Offal (chicken liver raw)         0.000000
# 17                                  Fish Fillet (cod)         0.000000
# 18  Dried/Salted/Smoked/Brined Fish (Fish, cod, At...         0.000000
# 19                                            Cassava         0.000000
# 20                                          plantains         1.953792
# 21                                         maize/corn        11.894953
# 22                                     sweet potatoes         0.000000
# 23                                               yams         0.000000
# 24                                           avocados         0.000000
# 25                                            papayas         0.000000
# 26                                            coconut         0.000000
# 27                                            oranges         0.000000
# 28                                               lime         0.000000
# 29                                 shiitake mushrooms         0.000000
# 30                          Edible Offal (pork liver)         0.403457

# %%
# Filtering and excluding the 0 from the local and import food list 
local_import_food[local_import_food['Quantity (100g)'] != 0]
# Out:
#                          Food  Quantity (100g)
# 4                 Soybean Oil         1.080714
# 8               Beans (Black)         0.211583
# 12                    Cheese          1.310191
# 20                  plantains         1.953792
# 21                 maize/corn        11.894953
# 30  Edible Offal (pork liver)         0.403457

# %%
# Total nutrients of local & import food with minimum cost diet
total_nutrients(A_ub_LI, local_import_food)
# Out:
#                          Nutrition  Total_nutrients
# 0                       Sodium, Na      1078.205414
# 1                           Energy      2978.887534
# 2                          Protein        85.756457
# 3             Fiber, total dietary        28.000000
# 4                      Folate, DFE       655.618434
# 5                      Calcium, Ca      1000.000000
# 6      Carbohydrate, by difference       285.738588
# 7                         Iron, Fe        18.000000
# 8                    Magnesium, Mg       590.910027
# 9                           Niacin        28.608446
# 10                   Phosphorus, P      1947.881722
# 11                    Potassium, K      4700.000000
# 12                      Riboflavin         2.592894
# 13                         Thiamin         2.117027
# 14                  Vitamin A, RAE      3253.767143
# 15                    Vitamin B-12        11.878694
# 16                     Vitamin B-6         1.947837
# 17  Vitamin C, total ascorbic acid       127.042924
# 18    Vitamin E (alpha-tocopherol)        15.000000
# 19       Vitamin K (phylloquinone)        90.000000
# 20                        Zinc, Zn        13.688249

# %%
# [B] What is total cost for population of interest? - Part A: Population Function

# Population function from project 1

def population_1year(year,sex,age,place):    
    if sex == 'F':
        gender = "FE"
    else:
        gender = "MA"

    lower_range = age
    while (lower_range % 5) != 0:
        lower_range -= 1
    
    upper_range = age 
    while ((upper_range-4) % 5) != 0:
        upper_range += 1

    if lower_range < 10:
        lower_str = "0" + str(lower_range)
    else:
        lower_str = str(lower_range)

    if upper_range < 10:
        upper_str = "0" + str(upper_range)
    else:
        upper_str = str(upper_range)
        
    data = "SP.POP." + lower_str + upper_str + "." + gender
    
    variable_labels = {data:"Population"}
    world = wbdata.get_dataframe(variable_labels, country=place, parse_dates=True)
    
    filtered = world[world.index.year == year]
    if filtered.empty:
        return 0
    return filtered.iloc[0]['Population'] / 5


#Getting the population by year, gender, age range and place.
#Coded based on population_1year function
def population(year,sex,age_range,place):
    lower_range = age_range[0]
    higher_range = age_range[1]
    population = 0
    
    while higher_range >= lower_range:
        population += population_1year(year,sex,lower_range,place)
        lower_range += 1

    return population
        
'''
Instruction for using the population function:
1. Year is limited to be between 1960 to 2024.
2. Type either 'F' or 'M' for gender.
3. See "wbdata.get_countries()"  for country code
4. About age range: 
    a. Type (lower range, upper range)
        i. It is inclusive, which mean the range (15,19) include the population for both age 15 and age 19.
    b. lower range has to be: 0 - 78
    c. upper range has to be: 1 - 79 
    d. Upper range has to be greater than lower range
'''

#Example:
print(population_1year(2021, 'F',19,'HTI'))
print(population(2021, 'F', (15,19), 'HTI'))
print(population(2021, 'F', (43,78), 'HTI'))
# Out:
# 113653.0
# 568265.0
# 1213870.4

# %%
# [B] What is total cost for population of interest? - Part B: Calculating Total cost 

# Total cost of the population of one age and one gender in one country on input year
# Cost of one day
def total_cost(year, gender, age, country, cost, A_ub, food_list):
    b_ub = b_ub_age_gender(age, gender)
    df_food = minimum_cost(A_ub, b_ub, cost, food_list)
    return sum(list(df_food['Quantity (100g)'] * cost)) * population_1year(year, gender, age, country)

# Total cost of the population of the input country on input year
def total_cost_whole_country(year, country, cost, A_ub, food_list):

    # Getting total cost for one gender
    def total_cost_one_gender(gender):

        # Adding population for 80UP as my population does not include that
        if gender == 'F':
            g = 'FE'
        else: 
            g = 'MA'

        data = "SP.POP.80UP." + g
    
        variable_labels = {data:"Population"}
        world = wbdata.get_dataframe(variable_labels, country=country, parse_dates=True)  
        filtered = world[world.index.year == year]
        total = filtered.iloc[0]['Population']

        for i in range(79):
            total += total_cost(year, gender, i, country, cost, A_ub,food_list)
        return total
        
    df = pd.DataFrame({'Gender': ['Male','Female','Total'],
            'Cost': [total_cost_one_gender('M'), total_cost_one_gender('F'), total_cost_one_gender('M')+total_cost_one_gender('F')]})
    return df

# %%
# Total cost for local food only for one day 
total_cost_whole_country(2024, 'HTI', c, A_ub, food_list)
# Out:
#    Gender          Cost
# 0    Male  1.321420e+07
# 1  Female  1.311899e+07
# 2   Total  2.633319e+07

# %%
# Total cost for having both local and import food for one day 
total_cost_whole_country(2024, 'HTI', c_LI, A_ub_LI, food_list_LI)
# Out:
#    Gender          Cost
# 0    Male  1.407282e+07
# 1  Female  1.425833e+07
# 2   Total  2.833115e+07

# %%
# [C] Sensitivity of solution 

# Cost of one day of meal of the person with input age and input gender
def one_day_cost(gender, age, cost, A_ub, food_list):
    b_ub = b_ub_age_gender(age, gender)
    df_food = minimum_cost(A_ub, b_ub, cost, food_list)
    return sum(list(df_food['Quantity (100g)'] * cost))

# Sensitivity 
# Assumption: A_ub, the cost and the list of food have the same order
def sensitivity(gender, age, cost, A_ub, food_list, food_with_price_change):

    index = food_list.index(food_with_price_change)
    
    percentage_change = [0, 5, 10, 50, 100, 200]
    b_ub = b_ub_age_gender(age, gender)
    df = {'Food': food_list + ['Total Price']}
    
    for i in percentage_change:
        new_cost = cost[:]
        new_cost[index] *= (1+(0.01*i))
        df_food = minimum_cost(A_ub, b_ub, new_cost, food_list)
        df[str(i)+"% change for " + food_with_price_change] = list(df_food['Quantity (100g)']) + [one_day_cost(gender, age, new_cost, A_ub, food_list)]

    return pd.DataFrame(df)
        
maize_corn_sensitivity = sensitivity('F', 20, c , A_ub,food_list, 'maize/corn')
maize_corn_sensitivity
# Out:
#                                          Food  0% change for maize/corn  \
# 0                        Cabbage (green, raw)                  0.958180
# 1                                       Mango                  0.000000
# 2                                     Chicken                  0.000000
# 3   Rice (white, long grain, unenriched, raw)                  0.000000
# 4                                 Soybean Oil                  1.122487
# 5         Bread (white, enriched, unbleached)                  0.000000
# 6                         Onion (yellow, raw)                  0.000000
# 7                                   Raw Sugar                  0.000000
# 8                               Beans (Black)                  1.779426
# 9                                   Fish/tuna                  0.000000
# 10                                       Eggs                  1.589737
# 11                                       Corn                  0.000000
# 12                                    Cheese                   0.734404
# 13   Beef(Bovine Meat) ; (80% lean, 20% fat)                   0.000000
# 14                                    Cassava                  0.000000
# 15                                  plantains                  0.000000
# 16                                 maize/corn                 10.783699
# 17                             sweet potatoes                  0.000000
# 18                                       yams                  0.121205
# 19                                   avocados                  0.000000
# 20                                    papayas                  0.000000
# 21                                    coconut                  0.000000
# 22                                    oranges                  0.000000
# 23                                       lime                  0.000000
# 24                         shiitake mushrooms                  0.000000
# 25                                Total Price                  2.367620
#
#     5% change for maize/corn  10% change for maize/corn  \
# 0                   0.958180                   0.958180
# 1                   0.000000                   0.000000
# 2                   0.000000                   0.000000
# 3                   0.000000                   0.000000
# 4                   1.122487                   1.122487
# 5                   0.000000                   0.000000
# 6                   0.000000                   0.000000
# 7                   0.000000                   0.000000
# 8                   1.779426                   1.779426
# 9                   0.000000                   0.000000
# 10                  1.589737                   1.589737
# 11                  0.000000                   0.000000
# 12                  0.734404                   0.734404
# 13                  0.000000                   0.000000
# 14                  0.000000                   0.000000
# 15                  0.000000                   0.000000
# 16                 10.783699                  10.783699
# 17                  0.000000                   0.000000
# 18                  0.121205                   0.121205
# 19                  0.000000                   0.000000
# 20                  0.000000                   0.000000
# 21                  0.000000                   0.000000
# 22                  0.000000                   0.000000
# 23                  0.000000                   0.000000
# 24                  0.000000                   0.000000
# 25                  2.394579                   2.421538
#
#     50% change for maize/corn  100% change for maize/corn  \
# 0                    0.499833                    0.170649
# 1                    0.000000                    0.000000
# 2                    0.000000                    0.000000
# 3                    0.000000                    0.000000
# 4                    1.139814                    1.164196
# 5                    0.000000                    0.000000
# 6                    0.000000                    0.000000
# 7                    0.000000                    0.000000
# 8                    2.147522                    2.100410
# 9                    0.431403                    0.256823
# 10                   0.517591                    1.095455
# 11                   0.000000                    0.000000
# 12                   0.720144                    0.587360
# 13                   0.000000                    0.000000
# 14                   0.000000                    0.000000
# 15                   0.959670                    1.658710
# 16                   7.916539                    5.089877
# 17                   0.000000                    0.000000
# 18                   0.363774                    0.255387
# 19                   0.000000                    0.000000
# 20                   0.000000                    0.000000
# 21                   0.000000                    0.000000
# 22                   0.000000                    2.282712
# 23                   0.000000                    0.000000
# 24                   0.000000                    0.000000
# 25                   2.607948                    2.742624
#
#     200% change for maize/corn
# 0                     0.992529
# 1                     0.000000
# 2                     0.000000
# 3                     0.000000
# 4                     1.217973
# 5                     0.571696
# 6                     0.000000
# 7                     0.000000
# 8                     1.667177
# 9                     0.554274
# 10                    0.761395
# 11                    0.000000
# 12                    0.187634
# 13                    0.000000
# 14                    0.000000
# 15                    0.000000
# 16                    0.000000
# 17                    0.000000
# 18                    0.720539
# 19                    0.000000
# 20                    0.000000
# 21                    0.000000
# 22                   10.075976
# 23                    0.000000
# 24                    0.000000
# 25                    2.843620

# %%
# Filtered maize/corn sensitivity
filtered_maize_corn_sensitivity = maize_corn_sensitivity[(maize_corn_sensitivity.iloc[:, 1:] != 0).any(axis=1)]
filtered_maize_corn_sensitivity
# Out:
#                                    Food  0% change for maize/corn  \
# 0                  Cabbage (green, raw)                  0.958180
# 4                           Soybean Oil                  1.122487
# 5   Bread (white, enriched, unbleached)                  0.000000
# 8                         Beans (Black)                  1.779426
# 9                             Fish/tuna                  0.000000
# 10                                 Eggs                  1.589737
# 12                              Cheese                   0.734404
# 15                            plantains                  0.000000
# 16                           maize/corn                 10.783699
# 18                                 yams                  0.121205
# 22                              oranges                  0.000000
# 25                          Total Price                  2.367620
#
#     5% change for maize/corn  10% change for maize/corn  \
# 0                   0.958180                   0.958180
# 4                   1.122487                   1.122487
# 5                   0.000000                   0.000000
# 8                   1.779426                   1.779426
# 9                   0.000000                   0.000000
# 10                  1.589737                   1.589737
# 12                  0.734404                   0.734404
# 15                  0.000000                   0.000000
# 16                 10.783699                  10.783699
# 18                  0.121205                   0.121205
# 22                  0.000000                   0.000000
# 25                  2.394579                   2.421538
#
#     50% change for maize/corn  100% change for maize/corn  \
# 0                    0.499833                    0.170649
# 4                    1.139814                    1.164196
# 5                    0.000000                    0.000000
# 8                    2.147522                    2.100410
# 9                    0.431403                    0.256823
# 10                   0.517591                    1.095455
# 12                   0.720144                    0.587360
# 15                   0.959670                    1.658710
# 16                   7.916539                    5.089877
# 18                   0.363774                    0.255387
# 22                   0.000000                    2.282712
# 25                   2.607948                    2.742624
#
#     200% change for maize/corn
# 0                     0.992529
# 4                     1.217973
# 5                     0.571696
# 8                     1.667177
# 9                     0.554274
# 10                    0.761395
# 12                    0.187634
# 15                    0.000000
# 16                    0.000000
# 18                    0.720539
# 22                   10.075976
# 25                    2.843620

# %%
# [C] Visualization

# input of sensitivity_of_food is expected to be the dataframe produced from sensitivity() function
def visualization(sensitivity_of_food, food_with_price_change):
    percentage_change = [0, 5, 10, 50, 100, 200]
    list_of_price = list((sensitivity_of_food).iloc[-1])[1:]
    
    plt.title("Sensitivity of Meal Cost to " + food_with_price_change + " Price Changes")
    plt.xlabel("Price Change (%)")
    plt.ylabel("Total Meal Cost in USD for One Day")
    
    plt.plot(percentage_change, list_of_price)
    plt.show()

visualization(maize_corn_sensitivity, 'maize/corn')

# %%
print("Local only:")
# One day cost for female 30 years old
print("One day cost for female 10 years old: ", one_day_cost('F', 10, c, A_ub, food_list))
      
# One day cost for male 30 years old
print("One day cost for male 10 years old: ", one_day_cost('M', 10, c, A_ub, food_list))

# One day cost for female 30 years old
print("One day cost for female 30 years old: ", one_day_cost('F', 30, c, A_ub, food_list))
      
# One day cost for male 30 years old
print("One day cost for male 30 years old: ", one_day_cost('M', 30, c, A_ub, food_list))

print("Local and Import:")
# One day cost for female 30 years old
print("One day cost for female 10 years old: ", one_day_cost('F', 10, c_LI, A_ub_LI, food_list_LI))
      
# One day cost for male 30 years old
print("One day cost for male 10 years old: ", one_day_cost('M', 10, c_LI, A_ub_LI, food_list_LI))

# One day cost for female 30 years old
print("One day cost for female 30 years old: ", one_day_cost('F', 30, c_LI, A_ub_LI, food_list_LI))
      
# One day cost for male 30 years old
print("One day cost for male 30 years old: ", one_day_cost('M', 30, c_LI, A_ub_LI, food_list_LI))
# Out:
# Local only:
# One day cost for female 10 years old:  2.2146331083722846
# One day cost for male 10 years old:  2.264830500144178
# One day cost for female 30 years old:  2.367619524507332
# One day cost for male 30 years old:  2.504865780728396
# Local and Import:
# One day cost for female 10 years old:  2.5198859050538296
# One day cost for male 10 years old:  2.52496425657114
# One day cost for female 30 years old:  2.533275334569239
# One day cost for male 30 years old:  2.6133090502112686
